# %%
import pandas  as pd

# %%
from google.colab import drive
# !cd ~
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/Colab Notebooks/unsupervised_project/MSA"
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/unsupervised_project/MSA
# 'family msa_gen_vector_iadf+.ipynb'
#  msa_gen_vector_iadf+.ipynb
#  msa_gen_vector_iadf.ipynb
#  msa.ipynb
#  RE_df.gsheet
#  RE_df.tsv
#  res_of_iadf_pca.csv
#  res_of_iadf_plus_pca
#  res_of_iadf_plus_pca.csv
#  res_of_pca_tfidf.csv
# 'results summerizetion.ipynb'
# 'submission of PCA msa_gen_vector_iadf+.ipynb'
# 'submission of PCA msa_gen_vector_iadf.ipynb'
# 'submission of PCA msa_gen_vector_tf_idf.ipynb'
# 'submission of TSNE msa_gen_vector_iadf+.ipynb'

# %%
df_iadf_pca = pd.read_csv('res_of_iadf_pca.csv')
df_iadf_plus_pca = pd.read_csv('res_of_iadf_plus_pca.csv')
df_tfidf_pca = pd.read_csv('res_of_pca_tfidf.csv')

# %%
df_iadf_plus_pca.groupby(['algo'])['fmi'].median()
# Out:
# algo
# <class 'sklearn.cluster._dbscan.DBSCAN'>                            0.844683
# <class 'sklearn.covariance._elliptic_envelope.EllipticEnvelope'>    0.883840
# <class 'sklearn.ensemble._iforest.IsolationForest'>                 0.779080
# <class 'sklearn.svm._classes.OneClassSVM'>                          0.685129
# Name: fmi, dtype: float64

# %%
df_iadf_pca.groupby(['algo'])['fmi'].median()
# Out:
# algo
# <class 'sklearn.cluster._dbscan.DBSCAN'>                            0.838569
# <class 'sklearn.covariance._elliptic_envelope.EllipticEnvelope'>    0.883861
# <class 'sklearn.ensemble._iforest.IsolationForest'>                 0.774114
# <class 'sklearn.svm._classes.OneClassSVM'>                          0.685129
# Name: fmi, dtype: float64

# %%
df_tfidf_pca.groupby(['algo'])['fmi'].median()
# Out:
# algo
# <class 'sklearn.covariance._elliptic_envelope.EllipticEnvelope'>    0.895288
# <class 'sklearn.ensemble._iforest.IsolationForest'>                 0.787433
# <class 'sklearn.svm._classes.OneClassSVM'>                          0.685129
# Name: fmi, dtype: float64

# %%
df_tfidf_pca[df_tfidf_pca['algo'] == "<class 'sklearn.covariance._elliptic_envelope.EllipticEnvelope'>"].sort_values(by='fmi', ascending = False)
# Out:
#     Unnamed: 0                                               algo  \
# 0          126  <class 'sklearn.covariance._elliptic_envelope....
# 1          101  <class 'sklearn.covariance._elliptic_envelope....
# 2          137  <class 'sklearn.covariance._elliptic_envelope....
# 3          135  <class 'sklearn.covariance._elliptic_envelope....
# 4          114  <class 'sklearn.covariance._elliptic_envelope....
# 5          142  <class 'sklearn.covariance._elliptic_envelope....
# 6          133  <class 'sklearn.covariance._elliptic_envelope....
# 7          122  <class 'sklearn.covariance._elliptic_envelope....
# 10         105  <class 'sklearn.covariance._elliptic_envelope....
# 11         119  <class 'sklearn.covariance._elliptic_envelope....
# 12         111  <class 'sklearn.covariance._elliptic_envelope....
# 9          140  <class 'sklearn.covariance._elliptic_envelope....
# 8          113  <class 'sklearn.covariance._elliptic_envelope....
# 13         118  <class 'sklearn.covariance._elliptic_envelope....
# 14         143  <class 'sklearn.covariance._elliptic_envelope....
# 15         128  <class 'sklearn.covariance._elliptic_envelope....
# 16         112  <class 'sklearn.covariance._elliptic_envelope....
# 17         141  <class 'sklearn.covariance._elliptic_envelope....
# 18         129  <class 'sklearn.covariance._elliptic_envelope....
# 19         132  <class 'sklearn.covariance._elliptic_envelope....
# 20         125  <class 'sklearn.covariance._elliptic_envelope....
# 21         134  <class 'sklearn.covariance._elliptic_envelope....
# 22         110  <class 'sklearn.covariance._elliptic_envelope....
# 24         108  <class 'sklearn.covariance._elliptic_envelope....
# 25         107  <class 'sklearn.covariance._elliptic_envelope....
# 26         115  <class 'sklearn.covariance._elliptic_envelope....
# 27         120  <class 'sklearn.covariance._elliptic_envelope....
# 28         121  <class 'sklearn.covariance._elliptic_envelope....
# 29         109  <class 'sklearn.covariance._elliptic_envelope....
# 30         100  <class 'sklearn.covariance._elliptic_envelope....
# 32         131  <class 'sklearn.covariance._elliptic_envelope....
# 33         117  <class 'sklearn.covariance._elliptic_envelope....
# 34          96  <class 'sklearn.covariance._elliptic_envelope....
# 35          97  <class 'sklearn.covariance._elliptic_envelope....
# 36         138  <class 'sklearn.covariance._elliptic_envelope....
# 37         139  <class 'sklearn.covariance._elliptic_envelope....
# 39         130  <class 'sklearn.covariance._elliptic_envelope....
# 38         106  <class 'sklearn.covariance._elliptic_envelope....
# 41         104  <class 'sklearn.covariance._elliptic_envelope....
# 42          98  <class 'sklearn.covariance._elliptic_envelope....
# 43         116  <class 'sklearn.covariance._elliptic_envelope....
# 45         136  <class 'sklearn.covariance._elliptic_envelope....
# 49         103  <class 'sklearn.covariance._elliptic_envelope....
# 50         127  <class 'sklearn.covariance._elliptic_envelope....
# 51          99  <class 'sklearn.covariance._elliptic_envelope....
# 64         123  <class 'sklearn.covariance._elliptic_envelope....
# 65         102  <class 'sklearn.covariance._elliptic_envelope....
# 66         124  <class 'sklearn.covariance._elliptic_envelope....
#
#           family_lable       ari       fmi  homogeneity  completeness  \
# 0            Moraxella  0.744783  0.956850     0.732160      0.554216
# 1          Arthrospira  0.354997  0.939391     0.542999      0.190615
# 2         Streptomyces  0.543700  0.938650     0.616794      0.341411
# 3         Sphaerotilus  0.595258  0.936969     0.639252      0.393718
# 4         Enterobacter  0.649446  0.935851     0.480714      0.424952
# 5              Thermus  0.436266  0.929727     0.563004      0.253442
# 6           Salmonella  0.465438  0.928995     0.574725      0.277548
# 7           Klebsiella  0.282824  0.920936     0.491663      0.147933
# 10      Brevibacterium  0.282335  0.920078     0.491663      0.147933
# 11             Frankia  0.282335  0.920078     0.491663      0.147933
# 12         Deinococcus  0.282335  0.920078     0.491663      0.147933
# 9         Thermoplasma  0.282335  0.920078     0.491663      0.147933
# 8          Diplococcus  0.282335  0.920078     0.491663      0.147933
# 13      Flavobacterium  0.425788  0.918391     0.549489      0.250483
# 14         Xanthomonas  0.343148  0.915241     0.303167      0.151054
# 15           Neisseria  0.446434  0.914837     0.293392      0.221123
# 16       Desulfovibrio  0.254852  0.911570     0.470177      0.132686
# 17          Thermotoga  0.254852  0.911570     0.470177      0.132686
# 18            Nocardia  0.222674  0.901555     0.208811      0.080935
# 19         Rhodobacter  0.230315  0.901258     0.450754      0.120101
# 20       Methylococcus  0.230315  0.901258     0.450754      0.120101
# 21          Shewanella  0.230315  0.901258     0.450754      0.120101
# 22     Corynebacterium  0.230315  0.901258     0.450754      0.120101
# 24         Citrobacter  0.438215  0.897097     0.253067      0.223712
# 25          Chlorobium  0.108850  0.893479     0.100323      0.028312
# 26         Escherichia  0.229655  0.891907     0.116651      0.073707
# 27         Haemophilus  0.312323  0.887427     0.157920      0.124178
# 28        Helicobacter  0.064079  0.887359     0.025815      0.009650
# 29         Clostridium  0.052300  0.884706     0.019217      0.006940
# 30        Arthrobacter  0.052300  0.884706     0.019217      0.006940
# 32          Pyrococcus  0.087269  0.883881     0.042601      0.016512
# 33         Fischerella -0.030689  0.883840     0.021184      0.006374
# 34           Aeropyrum -0.030689  0.883840     0.021184      0.006374
# 35          Agmenellum -0.030689  0.883840     0.021184      0.006374
# 36          Sulfolobus -0.030689  0.883840     0.021184      0.006374
# 37        Thermococcus -0.030689  0.883840     0.021184      0.006374
# 39         Pseudomonas  0.293246  0.879290     0.149092      0.112857
# 38           Chlorella  0.293246  0.879290     0.149092      0.112857
# 41     Bifidobacterium -0.041450  0.867081     0.025372      0.009834
# 42       Agrobacterium -0.030709  0.866109     0.025699      0.006847
# 43         Eubacterium -0.030709  0.866109     0.025699      0.006847
# 45       Streptococcus  0.034119  0.855486     0.003521      0.002532
# 49         Bacteroides -0.052723  0.847882     0.029534      0.013463
# 50          Mycoplasma -0.052723  0.847882     0.029534      0.013463
# 51            Anabaena  0.096926  0.845568     0.023385      0.017702
# 64         Lactococcus -0.083040  0.811264     0.033053      0.030974
# 65            Bacillus -0.023024  0.809971     0.001389      0.001425
# 66  Methanocaldococcus -0.087616  0.800626     0.036247      0.032043
#
#     v_measure        tp        fp        fn        tn  family_size  re_size
# 0    0.630880  0.074074  0.000000  0.037037  0.888889           54        4
# 1    0.282175  0.019608  0.000000  0.058824  0.921569           51        1
# 2    0.439531  0.044586  0.000000  0.057325  0.898089          157        7
# 3    0.487303  0.056604  0.000000  0.056604  0.886792           53        3
# 4    0.451116  0.072727  0.018182  0.036364  0.872727           55        5
# 5    0.349537  0.033816  0.000000  0.067633  0.898551          207        7
# 6    0.374325  0.038462  0.000000  0.067308  0.894231          104        4
# 7    0.227434  0.019608  0.000000  0.078431  0.901961          102        2
# 10   0.227434  0.019608  0.000000  0.078431  0.901961           51        1
# 11   0.227434  0.019608  0.000000  0.078431  0.901961           51        1
# 12   0.227434  0.019608  0.000000  0.078431  0.901961           51        1
# 9    0.227434  0.019608  0.000000  0.078431  0.901961           51        1
# 8    0.227434  0.019608  0.000000  0.078431  0.901961           51        1
# 13   0.344107  0.038462  0.000000  0.076923  0.884615           52        2
# 14   0.201640  0.028846  0.009615  0.072115  0.889423          208        8
# 15   0.252182  0.044776  0.022388  0.055970  0.876866          268       18
# 16   0.206966  0.019608  0.000000  0.088235  0.892157          102        2
# 17   0.206966  0.019608  0.000000  0.088235  0.892157          102        2
# 18   0.116654  0.019417  0.009709  0.087379  0.883495          103        3
# 19   0.189666  0.019608  0.000000  0.098039  0.882353           51        1
# 20   0.189666  0.019608  0.000000  0.098039  0.882353           51        1
# 21   0.189666  0.019608  0.000000  0.098039  0.882353           51        1
# 22   0.189666  0.019608  0.000000  0.098039  0.882353           51        1
# 24   0.237486  0.054545  0.036364  0.054545  0.854545           55        5
# 25   0.044161  0.009804  0.009804  0.098039  0.882353          102        2
# 26   0.090335  0.023697  0.028436  0.075829  0.872038          211       11
# 27   0.139031  0.037037  0.037037  0.067901  0.858025          162       12
# 28   0.014048  0.007299  0.019465  0.094891  0.878345          411       11
# 29   0.010197  0.006494  0.019481  0.097403  0.876623          154        4
# 30   0.010197  0.006494  0.019481  0.097403  0.876623          154        4
# 32   0.023799  0.009709  0.019417  0.097087  0.873786          103        3
# 33   0.009799  0.000000  0.019608  0.098039  0.882353           51        1
# 34   0.009799  0.000000  0.019608  0.098039  0.882353           51        1
# 35   0.009799  0.000000  0.019608  0.098039  0.882353           51        1
# 36   0.009799  0.000000  0.019608  0.098039  0.882353           51        1
# 37   0.009799  0.000000  0.019608  0.098039  0.882353           51        1
# 39   0.128468  0.037037  0.037037  0.074074  0.851852           54        4
# 38   0.128468  0.037037  0.037037  0.074074  0.851852           54        4
# 41   0.014174  0.000000  0.029126  0.106796  0.864078          103        3
# 42   0.010813  0.000000  0.019608  0.117647  0.862745           51        1
# 43   0.010813  0.000000  0.019608  0.117647  0.862745           51        1
# 45   0.002946  0.009375  0.053125  0.090625  0.846875          320       20
# 49   0.018495  0.000000  0.038462  0.115385  0.846154           52        2
# 50   0.018495  0.000000  0.038462  0.115385  0.846154           52        2
# 51   0.020150  0.018519  0.055556  0.092593  0.833333           54        4
# 64   0.031979  0.000000  0.090909  0.100000  0.809091          110       10
# 65   0.001407  0.007952  0.097416  0.093439  0.801193          503       53
# 66   0.034016  0.000000  0.090909  0.109091  0.800000           55        5

# %%
df_tfidf_pca['algo'] = df_tfidf_pca['algo'].astype(str)
